# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *

# set number as L
L=10

print(sqrt(L))
# Out:
# 3.1622776601683795

# %%
"problem 1.1.1"

import matplotlib.pyplot as plt
import numpy as np

# set number as L
L=10
# set numer as S for size
S=10000
random_number = np.random.uniform(low=0, high=L, size = S)

# create histogram

plt.hist(random_number, edgecolor = 'black')

plt.xlabel("position")
plt.ylabel("count")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
"problem 1.1.2"
# set number N
N=100
L=10
x = np.random.uniform(low=0, high=L, size=N)
y = np.random.uniform(low=0, high=L, size=N)

plt.scatter(x, y, c ="black")

# To show the plot
plt.xlabel("x-coordinate")
plt.ylabel("y-coordinate")
plt.show()

# %%
"Problem 1.1.3 Final Draft"
import numpy as np
import matplotlib.pyplot as plt
def initialize(L, N):
    x_pos = np.random.uniform(0, L, N)
    y_pos = np.random.uniform(0, L, N)
    angle = np.random.uniform(-np.pi, np.pi, N)
    
    return x_pos, y_pos, angle

def get_color(angle):
    hue = (angle + np.pi) / (2 * np.pi)
    return hue

L = 10
N = 100
x_pos, y_pos, angle = initialize(L, N)

# create plot and label direction
x_direct = np.cos(angle)
y_direct = np.sin(angle)
color = [get_color(angle)]
plt.figure(figsize = (10, 10))
plt.quiver(x_pos, y_pos, x_direct, y_direct, color)

# show quiver plot
plt.xlabel("x-coordinate")
plt.ylabel("y-coordinate")
plt.show()

# %%
"Problem 1.2.1 - Second Draft"
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# create figure and axis
fig, ax = plt.subplots()
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)

# number of vectors
num_vectors = 4

# initialize data and parameters
x_pos, y_pos, angle = initialize(10,1)
v = 1
delta_t = 1
N_steps = 100

# define direction for vectors
x_direct = np.cos(angle)
y_direct = np.sin(angle)
direction = np.array([x_direct, y_direct])

# starting position
start_position = x_pos, y_pos
quiver = ax.quiver(start_position, np.tile(direction[0], num_vectors), np.tile(direction[1], num_vectors))

# Function to update the position of the vectors
def update(frame):
    x_new = (x_pos + v * np.cos(angle) * delta_t) % L
    y_new = (y_pos + v * np.sin(angle) * delta_t) % L
    
    # update position
    quiver.set_offsets(x_new, y_new)
    
    return quiver,

# create the animation
num_frames = np.arange(N_steps)
ani = FuncAnimation(fig, update, frames=num_frames, interval=500)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12 num_vectors = 4
#      14 # initialize data and parameters
# ---> 15 x_pos, y_pos, angle = initialize(10,1)
#      16 v = 1
#      17 delta_t = 1
#
# NameError: name 'initialize' is not defined

# %%
"problem 1.2.1 Third Draft"

from matplotlib.animation import FuncAnimation

# parameters
v = 1
delta_t = 1
N_steps = 100
x_direct = np.cos(angle)
y_direct = np.sin(angle)
N = 1
L = 10

# initialize function
x_pos, y_pos, angle = initialize(10, 1)

# initial plot
fig, ax = plt.subplots()
ax.set_xlim(0, L)
ax.set_ylim(0, L)

# update position
def update_position(x_pos, y_pos, angle, v, delta_t, L):
    x_new = (x_pos + v * np.cos(angle) * delta_t) % L
    y_new = (y_pos + v * np.sin(angle) * delta_t) % L
    return x_new, y_new

# update function for the animation
def update(frame):
    global x_pos, y_pos, angle
    # updating position
    x_new, y_new = update_position(x_pos, y_pos, angle, v, delta_t, L)
    
    # clear previous plot
    ax.cla()
    ax.set_xlim(0,L)
    ax.set_ylim(0,L)
    
    # plotting new position
    ax.quiver(x_new, y_new, np.cos(angle), np.sin(angle), color='black')

# create animation
ani = FuncAnimation(fig, update, frames = np.arange(N_steps), interval = 500)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 15
#      12 L = 10
#      14 # initialize function
# ---> 15 x_pos, y_pos, angle = initialize(10, 1)
#      17 # initial plot
#      18 fig, ax = plt.subplots()
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
"Problem 1.2.1 - Final Draft"

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from matplotlib.animation import FuncAnimation


def initialize(L, N):
    x_pos = np.random.uniform(0, L, N)
    y_pos = np.random.uniform(0, L, N)
    angle = np.random.uniform(-np.pi, np.pi, N)
    
    return x_pos, y_pos, angle

# variables/paramaters
delta_t = 1
v = 1
L=10
N=1
N_steps=100
x_pos, y_pos, angle = initialize(L,N)

# initial plot
fig, ax = plt.subplots()
ax.set_xlim(0,L)
ax.set_ylim(0,L)

def update_position(x_pos, y_pos, angle, delta_t, v, L):
    x_new = (x_pos + v*np.cos(angle) * delta_t) % L
    y_new = (y_pos + v*np.sin(angle) * delta_t) % L
    
    return x_new, y_new

def update(frame):
    global x_pos, y_pos, angle
    # updating position
    x_pos, y_pos = update_position(x_pos, y_pos, angle, delta_t, v, L)
    
    ax.cla()
    ax.set_xlim(0,L)
    ax.set_ylim(0,L)
    
    # plot new points
    ax.quiver(x_pos, y_pos, np.cos(angle), np.sin(angle), color='black')

# create animation
ani = FuncAnimation(fig, func=update, frames=np.arange(N_steps), interval=500)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
"Problem 1.2.2 - Final Draft"

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from matplotlib.animation import FuncAnimation


def initialize(L, N):
    x_pos = np.random.uniform(0, L, N)
    y_pos = np.random.uniform(0, L, N)
    angle = np.random.uniform(-np.pi, np.pi, N)
    
    return x_pos, y_pos, angle

# variables/paramaters
delta_t = 1
v = 1
L=10
N= 2
N_steps=100
eta = 3
x_pos, y_pos, angle = initialize(L,N)

# initial plot
fig, ax = plt.subplots()
ax.set_xlim(0,L)
ax.set_ylim(0,L)

def update_position(x_pos, y_pos, angle, delta_t, v, L,eta):
    x_new = (x_pos + v*np.cos(angle) * delta_t) % L
    y_new = (y_pos + v*np.sin(angle) * delta_t) % L
    delta_angle = np.random.uniform(-eta/2, eta/2, N)
    angle_new = angle + delta_angle
    
    return x_new, y_new, angle_new


def update(frame):
    global x_pos, y_pos, angle
    # updating position
    x_pos, y_pos, angle = update_position(x_pos, y_pos, angle, delta_t, v, L,eta)
    
    ax.cla()
    ax.set_xlim(0,L)
    ax.set_ylim(0,L)
    
    # plot new points
    ax.quiver(x_pos, y_pos, np.cos(angle), np.sin(angle), color='black')

# create animation
ani = FuncAnimation(fig, func=update, frames=np.arange(N_steps), interval=500)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Problem 2.1

import matplotlib.pyplot as plt
import numpy as np

def find_neighbors(positions, target_index, L, r0):
    """
    finds the neighbors of an object within a radius in a periodic box
    
    Paramaters:
    positions (np.array): an array of positions of all objects.
    target_index(int): the index of the target object in the positions array
    L(float): the lenght of the sides of the square box (assuming a square box for simplicity)
    r0(float): the radius within which to search for neighbors.
    
    returns:
    neighbors (list): a list of indices of the neighboring objects
    """
    
    target_position = positions[target_index]
    neighbors = []
    
    for i, position in enumerate(positions):
        if i != target_index:
            # calculate the distance considering periodic boundaries
            dx = position[0] - target_position[0]
            dy = position[1] - target_position[1]
            dx = dx - L*np.round(dx / L)
            dy = dy - L*np.round(dy / L)
            distance = np.sqrt(dx**2 + dy**2)
            
            # check if the object is within the radius r0
            if distance < r0:
                neighbors.append(i)
            
    return neighbors

# lenght of box and circle thingy
L = 1.0
r0 = 0.3

# make objects
positions = np.random.uniform(0,L,(200, 2))

# choose object
object_of_interest_index = 25
object_of_interest = positions[object_of_interest_index]

# find neighbors
neighbors_indices = find_neighbors(positions, object_of_interest_index, L, r0)

fig, ax = plt.subplots()

# plotting orange circles
ax.scatter(positions[:,0], positions[:,1], color = 'orange', label='objects')

# object of interest in blue

ax.scatter(object_of_interest[0], object_of_interest[1], color = 'blue', marker = 's', label='object of interest')

# neighbors are magenta stars
for i, neighbor_index in enumerate(neighbors_indices):
    neighbor_position = positions[neighbor_index]
    if i == 0:
        ax.scatter(neighbor_position[0], neighbor_position[1], color = 'magenta', marker='*', label='neighbors')
    else:
        ax.scatter(neighbor_position[0], neighbor_position[1], color = 'magenta', marker='*')

# drawing the circle around the object of interest

circle = plt.Circle(object_of_interest, r0, color='black', fill = False)
ax.add_artist(circle)

ax.set_xlim(0,L)
ax.set_ylim(0,L)
ax.set_aspect('equal')
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
import numpy as np

def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    orientations = np.random.uniform(-np.pi, np.pi, N)
    return positions, orientations

def find_neighbors(positions, target_index, L, r0):
    
    target_positions = [positions_index]
    neighbors = []
    
    for i, positions in enumerate(positions):
        if i != target_index:
            # calculate boundaries
            dx = positions[:,0] - positions[i,0]
            dy = positions[:,1] - positions[i,1]
            dx = dx - L * np.round(dx/L)
            dy = dx - L * np.round(dy/L)
            distances = np.sqrt(dx**2 + dy**2)
            
            # check radius
            if 0 < distances < r0:
                neighbors.append(i)
    return neighbors


def align_orientations(neighbors, orientations, eta):
    if np.any(neighbors):
        average_orientation = np.arctan2(np.sin(orientations[neighbors]).mean(), np.cos(orientations[neighbors]).mean())
        new_orientation[i] = average_orientation + np.random.uniform(-eta/2, eta/2)
    else:
        # if no neighbors
        new_orientations[i] += np.random.uniform(-eta/2, eta/2)
    
    return new_orientations

def index(positions, N):
    for i in range (N):
        object_of_interest_index = i
        object_of_interest = positions[object_of_interest_index]
        
    return object_of_interest


object_of_interest = index(positions, N)


def evolve(time_steps, positions, object_of_interest, L, r0, orientations, eta, v, delta_t):
    for _ in range(time_steps):
        # find neighbors
        neighbors = find_neighbors(positions, positions[i], L, r0)
        orientations = align_orientation(neighbors, orientations, eta)
        
        # update positions
        positions[:,0] = (positions[:,0] + v * np.cos(orientations) * delta_t) % L
        positions[:,1] = (positions[:,1] + v * np.sin(orientations) * delta_t) % L
        
    return positions, orientations

# parametes
L = 10
N = 1
v = 1
r0 = 0
eta = 0
delta_t = 1
time_steps = 250

# initialize
positions, orientations = initialize(L,N)

fig, ax = plt.subplots()
ax.set_xlim(0,L)
ax.set_ylim(0,L)

def animate(frames):
    global positions, orientations
    # update particle's position and orientation
    positions, orientations = evolve(time_steps, positions, object_of_interest, L, r0, orientations, eta, v, delta_t)
    
    # clear previous plot
    ax.cla()
    ax.set_xlim(0,L)
    ax.set_ylim(0,L)
    
    # plotting new position
    ax.quiver(positions[:,0], positions[:,1], np.cos(orientations), np.sin(orientations), color='black')


# animate
ani = FuncAnimation(fig, animate,frames = 100,interval=500)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
"Problem 2.2"
import matplotlib.pyplot as plt
import numpy as np
def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    orientations = np.random.uniform(-np.pi, np.pi, N)
    return positions, orientations

def align_orientation_with_neighbors(positions, orientations, L, r0, eta):
    N = len(positions)
    new_orientations = np.copy(orientations)
    
    for i in range(N):
        # find neighbors
        dx = positions[:,0] - positions[i,0]
        dy = positions[:,1] - positions[i,1]
        dx = dx - L * np.round(dx/L)
        dy = dy - L * np.round(dx/L)
        distances = np.sqrt(dx**2 + dy**2)
        neighbors = (distances < r0) & (distances > 0) # exclude r = 0, itself
        
        # calculate the average orientation of neighbors
        if np.any(neighbors):
            average_orientation = np.arctan2(np.sin(orientations[neighbors]).mean(), np.cos(orientations[neighbors]).mean())
            new_orientations[i] = average_orientation + np.random.uniform(-eta/2,eta/2)
        else:
            # if no  neighbors, add random noise
            new_orientations[i] += np.random.uniform(-eta/2,eta/2)
    return new_orientations

# evolve the system with interactions
def evolve(positions, orientations,L,r0,eta,delta_t, time_steps):
    for _ in range(time_steps):
        # align orientations with neighbors
        orientations = align_orientation_with_neighbors(positions, orientations, L, r0, eta)
        
        # updative positions based on orientations
        positions[:,0] = (positions[:,0] + v * np.cos(orientations) * delta_t) % L
        positions[:,1] = (positions[:,1] + v * np.sin(orientations) * delta_t) % L
    
    return positions, orientations

# parametes
L = 10
N = 200
v = 1
r0 = 1
eta = 0.1
delta_t = 1
time_steps = 250

# initialize
positions, orientations = initialize(L,N)
positions, orientations = evolve(positions, orientations, L, r0, eta, delta_t, time_steps)

plt.figure(figsize=(10,6))
plt.quiver(positions[:, 0], positions[:, 1], np.cos(orientations), np.sin(orientations))
plt.xlim(0, L)
plt.ylim(0, L)
plt.title('Snapshot of Interacting Objects with Angular Noise')
plt.xlabel('x-coordinate')
plt.ylabel('y-coordinate')
plt.show()

# %%
"Problem 3.3"
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats


def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    angle = np.random.uniform(-np.pi, np.pi, N)
    return positions, angle

def align_angle_with_neighbors(positions, angle, L, r0, eta):
    N = len(positions)
    new_angle = np.copy(angle)
    
    for i in range(N):
        # find neighbors
        dx = positions[:,0] - positions[i,0]
        dy = positions[:,1] - positions[i,1]
        dx = dx - L * np.round(dx/L)
        dy = dy - L * np.round(dy/L)
        distances = np.sqrt(dx**2 + dy**2)
        neighbors = (distances < r0) & (distances > 0) # exclude r = 0, itself
        
        # calculate the average orientation of neighbors
        if np.any(neighbors):
            average_angle = np.arctan2(np.sin(angle[neighbors]).mean(), 
                                       np.cos(angle[neighbors]).mean())
            new_angle[i] = average_angle + np.random.uniform(-eta/2,eta/2)
        else:
            # if no  neighbors, add random noise
            new_angle[i] += np.random.uniform(-eta/2, eta/2)
    return new_angle

# evolve the system with interactions

magnitudes = []


# initialize parameters
N = 1
L = 25
r0 = 1
eta = 0
time_steps = 500
delta_t = 1
v = 1

positions, angle = initialize(L,N)


for _ in range(500):
    angle = align_angle_with_neighbors(positions, angle, L, r0, eta)
    
    positions[:,0] = (positions[:,0] + v * np.cos(angle) * delta_t) % L
    positions[:,1] = (positions[:,1] + v * np.sin(angle) * delta_t) % L
    
    vx = v * np.cos(angle).sum()
    vy = v * np.sin(angle).sum()
    
    # calculate total velocity
    
    v_total = np.sqrt(vx**2 + vy**2)
    
    magnitudes.append(v_total)
    
    

def order_parameter(v, positions, angle, L, eta, delta_t, time_steps, r0, N):
    
    array = np.array(magnitudes)
    
    va = array / (N*v)
    return va




time = np.arange(time_steps)
va = order_parameter(v, positions, angle, L, eta, delta_t, time_steps, r0, N)

plt.plot(time, va)

avg = np.median(va)



print(avg)






#plt.xlim(-50,550)
#plt.ylim(0,1)
#plt.show()
# Out:
# 1.0

# %%
"Problem 3.2"
import matplotlib.pyplot as plt
import numpy as np

def initialize(L,N):
    positions = np.random.uniform(0,L,(N,2))
    angle = np.random.uniform(-np.pi, np.pi, N)
    return positions,angle

def update_position_with_noise(positions,angle,eta,delta_t,v,L):
    delta_angle = np.random.uniform(-eta/2, eta/2, N) # N to make sure all particles have a changing angle
    new_angle = angle + delta_angle
    return new_angle

def order_parameter(positions, angle,L,eta,delta_t,time_steps, N):
    vx_list = []
    vy_list = []
    
    for t in range(time_steps):
        angle = update_position_with_noise(positions,angle,eta,delta_t,v,L)
        
        # calculate components
        velocities = np.zeros_like(positions)
        velocities[:,0] = v * np.cos(angle)
        velocities[:,1] = v * np.sin(angle)
        
        # update position
        positions[:,0] = (positions[:,0] * v * np.cos(angle) * delta_t) % L
        positions[:,1] = (positions[:,1] * v * np.sin(angle) * delta_t) % L
        
        
        vx = np.sum(velocities[:,0])
        vy = np.sum(velocities[:,1])
        
        
        vx_list.append(vx)
        vy_list.append(vy)
        
    # find magnitudes
    vx_array = np.array(vx_list)
    vy_array = np.array(vy_list)
    velocity_magnitudes = np.sqrt(vx_array**2 + vy_array**2)
    
    # calculate order parameter
    va = velocity_magnitudes/(N*v)
        
    return va, angle


# parameters
N = 5000
L = 25
eta = 3
time_steps = 500
delta_t = 1
v = 1

positions, angle = initialize(L,N)
va = order_parameter(positions,angle, L, eta, delta_t, time_steps, N)

# plot
time = np.arange(time_steps)
for i in range(N):
    plt.plot(time, va, linewidth=.5)


plt.xlim(0,time_steps+1)
plt.ylim(0,1)
plt.show()

# %%
"Problem 3.3"
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats


def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    angle = np.random.uniform(-np.pi, np.pi, N)
    return positions, angle

def align_angle_with_neighbors(positions, angle, L, r0, eta):
    N = len(positions)
    new_angle = np.copy(angle)
    
    for i in range(N):
        # find neighbors
        dx = positions[:,0] - positions[i,0]
        dy = positions[:,1] - positions[i,1]
        dx = dx - L * np.round(dx/L)
        dy = dy - L * np.round(dy/L)
        distances = np.sqrt(dx**2 + dy**2)
        neighbors = (distances < r0) & (distances > 0) # exclude r = 0, itself
        
        # calculate the average orientation of neighbors
        if np.any(neighbors):
            average_angle = np.arctan2(np.sin(angle[neighbors]).mean(), 
                                       np.cos(angle[neighbors]).mean())
            new_angle[i] = average_angle + np.random.uniform(-eta/2,eta/2)
        else:
            # if no  neighbors, add random noise
            new_angle[i] += np.random.uniform(-eta/2, eta/2)
    return new_angle

# evolve the system with interactions

magnitudes = []


# initialize parameters
N = 5000
L = 25
r0 = 1
eta = 3
time_steps = 500
delta_t = 1
v = 1

positions, angle = initialize(L,N)


for _ in range(500):
    angle = align_angle_with_neighbors(positions, angle, L, r0, eta)
    
    positions[:,0] = (positions[:,0] + v * np.cos(angle) * delta_t) % L
    positions[:,1] = (positions[:,1] + v * np.sin(angle) * delta_t) % L
    
    vx = v * np.cos(angle).sum()
    vy = v * np.sin(angle).sum()
    
    # calculate total velocity
    
    v_total = np.sqrt(vx**2 + vy**2)
    
    magnitudes.append(v_total)
    
    

def order_parameter(v, positions, angle, L, eta, delta_t, time_steps, r0, N):
    
    array = np.array(magnitudes)
    
    va = array / (N*v)
    return va




time = np.arange(time_steps)
va = order_parameter(v, positions, angle, L, eta, delta_t, time_steps, r0, N)

plt.plot(time, va)

avg = np.median(va)



print(avg)






#plt.xlim(-50,550)
#plt.ylim(0,1)
#plt.show()
# Out:
# 0.6241791144095772

# %%
"Problem 3.3"
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats


def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    angle = np.random.uniform(-np.pi, np.pi, N)
    return positions, angle

def align_angle_with_neighbors(positions, angle, L, r0, eta):
    N = len(positions)
    new_angle = np.copy(angle)
    
    for i in range(N):
        # find neighbors
        dx = positions[:,0] - positions[i,0]
        dy = positions[:,1] - positions[i,1]
        dx = dx - L * np.round(dx/L)
        dy = dy - L * np.round(dy/L)
        distances = np.sqrt(dx**2 + dy**2)
        neighbors = (distances < r0) & (distances > 0) # exclude r = 0, itself
        
        # calculate the average orientation of neighbors
        if np.any(neighbors):
            average_angle = np.arctan2(np.sin(angle[neighbors]).mean(), 
                                       np.cos(angle[neighbors]).mean())
            new_angle[i] = average_angle + np.random.uniform(-eta/2,eta/2)
        else:
            # if no  neighbors, add random noise
            new_angle[i] += np.random.uniform(-eta/2, eta/2)
    return new_angle

# evolve the system with interactions

magnitudes = []


# initialize parameters
N = 1800
L = 15
r0 = 1
eta = .5
time_steps = 500
delta_t = 1
v = 1

positions, angle = initialize(L,N)


for _ in range(500):
    angle = align_angle_with_neighbors(positions, angle, L, r0, eta)
    
    positions[:,0] = (positions[:,0] + v * np.cos(angle) * delta_t) % L
    positions[:,1] = (positions[:,1] + v * np.sin(angle) * delta_t) % L
    
    vx = v * np.cos(angle).sum()
    vy = v * np.sin(angle).sum()
    
    # calculate total velocity
    
    v_total = np.sqrt(vx**2 + vy**2)
    
    magnitudes.append(v_total)
    
    

def order_parameter(v, positions, angle, L, eta, delta_t, time_steps, r0, N):
    
    array = np.array(magnitudes)
    
    va = array / (N*v)
    return va




time = np.arange(time_steps)
va = order_parameter(v, positions, angle, L, eta, delta_t, time_steps, r0, N)

plt.plot(time, va)

avg = np.median(va)



print(avg)






#plt.xlim(-50,550)
#plt.ylim(0,1)
#plt.show()
# Out:
# 0.9870916890941821

# %%
# Simulate vairaible parameters

from itertools import chain
import numpy as np

parameters = 

def initialize(parameters):
    

l_list = []

L = np.zeros_like(N)
L[0] = np.sqrt(N[0]/8)
L[1] = np.sqrt(N[1]/8)
l_list.append(L)
L_array = np.array(l_list)
print(L_array)
# Out:
# [[ 5 15]]

# %%
"Problem 3.4"
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats


def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    angle = np.random.uniform(-np.pi, np.pi, N)
    return positions, angle

def align_angle_with_neighbors(positions, angle, L, r0, eta):
    N = len(positions)
    new_angle = np.copy(angle)
    
    for i in range(N):
        # find neighbors
        dx = positions[:,0] - positions[i,0]
        dy = positions[:,1] - positions[i,1]
        dx = dx - L * np.round(dx/L)
        dy = dy - L * np.round(dy/L)
        distances = np.sqrt(dx**2 + dy**2)
        neighbors = (distances < r0) & (distances > 0) # exclude r = 0, itself
        
        # calculate the average orientation of neighbors
        if np.any(neighbors):
            average_angle = np.arctan2(np.sin(angle[neighbors]).mean(), 
                                       np.cos(angle[neighbors]).mean())
            new_angle[i] = average_angle + np.random.uniform(-eta/2,eta/2)
        else:
            # if no  neighbors, add random noise
            new_angle[i] += np.random.uniform(-eta/2, eta/2)
    return new_angle

# evolve the system with interactions



# initialize parameters
N = 1800
L = 15
r0 = 1
time_steps = 500
delta_t = 1
v = 1
noise = np.linspace(0,6,10)


def order_parameter(v, magnitudes, N):
    
    array = np.array(magnitudes)
    
    va = array / (N*v)
    return va

va_avg = []

for eta in noise:
    positions, angle = initialize(L,N)
    magnitudes = []
    for _ in range(500):
        angle = align_angle_with_neighbors(positions, angle, L, r0, eta)
        positions[:,0] = (positions[:,0] + v * np.cos(angle) * delta_t) % L
        positions[:,1] = (positions[:,1] + v * np.sin(angle) * delta_t) % L
        vx = v * np.cos(angle).sum()
        vy = v * np.sin(angle).sum()
        # calculate total velocity
        v_total = np.sqrt(vx**2 + vy**2)
        magnitudes.append(v_total)
        
    va = order_parameter(v, magnitudes, N)
    
    va_avg.append(np.median(va))

plt.scatter(noise, va_avg)
plt.show()

# %%
"Problem 3.4"
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats


def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    angle = np.random.uniform(-np.pi, np.pi, N)
    return positions, angle

def align_angle_with_neighbors(positions, angle, L, r0, eta):
    N = len(positions)
    new_angle = np.copy(angle)
    
    for i in range(N):
        # find neighbors
        dx = positions[:,0] - positions[i,0]
        dy = positions[:,1] - positions[i,1]
        dx = dx - L * np.round(dx/L)
        dy = dy - L * np.round(dy/L)
        distances = np.sqrt(dx**2 + dy**2)
        neighbors = (distances < r0) & (distances > 0) # exclude r = 0, itself
        
        # calculate the average orientation of neighbors
        if np.any(neighbors):
            average_angle = np.arctan2(np.sin(angle[neighbors]).mean(), 
                                       np.cos(angle[neighbors]).mean())
            new_angle[i] = average_angle + np.random.uniform(-eta/2,eta/2)
        else:
            # if no  neighbors, add random noise
            new_angle[i] += np.random.uniform(-eta/2, eta/2)
    return new_angle

# set parameters
r0 = 1
time_steps = 500
delta_t = 1
v = 1
noise = np.linspace(0,6,20)
params = [(5,200)]
color = ['purple']

def order_parameter(v, magnitudes, N):
    
    array = np.array(magnitudes)
    
    va = array / (N*v)
    return va

def find_va_median(noise, r0, v, delta_t):
    va_median = []
    positions, angle = initialize(L,N)
    for eta in noise:
        magnitudes = []
        
        for _ in range(500):
            angle = align_angle_with_neighbors(positions, angle, L, r0, eta)
            positions[:,0] = (positions[:,0] + v * np.cos(angle) * delta_t) % L
            positions[:,1] = (positions[:,1] + v * np.sin(angle) * delta_t) % L
            
            vx = v * np.cos(angle).sum()
            
            vy = v * np.sin(angle).sum()
            
            # calculate total velocity
            
            v_total = np.sqrt(vx**2 + vy**2)
            
            magnitudes.append(v_total)
            
        va = order_parameter(v, magnitudes, N)
        
        va_median.append(np.median(va))
        
    return va_median


for (L,N), color in zip(params, color):
    va_median = find_va_median(noise, r0, v, delta_t)
    plt.scatter(noise, va_median, label=f'L={L}, N={N}', color=color)
    
plt.xlabel('Noise Strength')
plt.ylabel('Order Parameter Average')
plt.title('Order Parameter Average vs. Noise Strength for Different L, N')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats


def initialize(L, N):
    positions = np.random.uniform(0, L, (N,2))
    angle = np.random.uniform(-np.pi, np.pi, N)
    return positions, angle

def align_angle_with_neighbors(positions, angle, L, r0, eta):
    N = len(positions)
    new_angle = np.copy(angle)
    
    for i in range(N):
        # find neighbors
        dx = positions[:,0] - positions[i,0]
        dy = positions[:,1] - positions[i,1]
        dx = dx - L * np.round(dx/L)
        dy = dy - L * np.round(dy/L)
        distances = np.sqrt(dx**2 + dy**2)
        neighbors = (distances < r0) & (distances > 0) # exclude r = 0, itself
        
        # calculate the average orientation of neighbors
        if np.any(neighbors):
            average_angle = np.arctan2(np.sin(angle[neighbors]).mean(), 
                                       np.cos(angle[neighbors]).mean())
            new_angle[i] = average_angle + np.random.uniform(-eta/2,eta/2)
        else:
            # if no  neighbors, add random noise
            new_angle[i] += np.random.uniform(-eta/2, eta/2)
    return new_angle

# set parameters
r0 = 1
time_steps = 500
delta_t = 1
v = 1
noise = np.linspace(0,6,15)
params = [(5,200), (15, 1800),(25,5000)]
color = ['purple','blue','teal']

def order_parameter(v, magnitudes, N):
    
    array = np.array(magnitudes)
    
    va = array / (N*v)
    return va

def find_va_median(noise, r0, v, delta_t):
    va_median = []
    positions, angle = initialize(L,N)
    for eta in noise:
        magnitudes = []
        
        for _ in range(500):
            angle = align_angle_with_neighbors(positions, angle, L, r0, eta)
            positions[:,0] = (positions[:,0] + v * np.cos(angle) * delta_t) % L
            positions[:,1] = (positions[:,1] + v * np.sin(angle) * delta_t) % L
            
            vx = v * np.cos(angle).sum()
            
            vy = v * np.sin(angle).sum()
            
            # calculate total velocity
            
            v_total = np.sqrt(vx**2 + vy**2)
            
            magnitudes.append(v_total)
            
        va = order_parameter(v, magnitudes, N)
        
        va_median.append(np.median(va))
        
    return va_median


for (L,N), color in zip(params, color):
    va_median = find_va_median(noise, r0, v, delta_t)
    plt.scatter(noise, va_median, label=f'L={L}, N={N}', color=color)
    
plt.xlabel('Noise Strength')
plt.ylabel('Order Parameter Average')
plt.title('Order Parameter Average vs. Noise Strength for Different L, N')
plt.grid(True)
plt.legend()
plt.show()
